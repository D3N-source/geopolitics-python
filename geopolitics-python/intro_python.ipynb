# %%
print("Ciao, analista geopolitico 👋")
# Out:
# Ciao, analista geopolitico 👋

# %%
country = "Ucraina"
year = 2024
conflict = True

# %%
countries = ["Ucraina", "Russia", "Romania", "Polonia"]

# %%
military_spending = {
    "Russia": 86,
    "Ucraina": 44,
    "Romania": 8
}

# %%
for c in countries:
    print(c)
# Out:
# Ucraina
# Russia
# Romania
# Polonia

# %%
import pandas as pd

data = {
    "Country": ["Russia", "Ucraina", "Romania", "Polonia"],
    "Military_Spending_Billion_USD": [86, 44, 8, 22]
}

df = pd.DataFrame(data)
df
# Out:
#    Country  Military_Spending_Billion_USD
# 0   Russia                             86
# 1  Ucraina                             44
# 2  Romania                              8
# 3  Polonia                             22

# %%
df.describe()
# Out:
#        Military_Spending_Billion_USD
# count                       4.000000
# mean                       40.000000
# std                        34.058773
# min                         8.000000
# 25%                        18.500000
# 50%                        33.000000
# 75%                        54.500000
# max                        86.000000

# %%
import matplotlib.pyplot as plt

plt.bar(df["Country"], df["Military_Spending_Billion_USD"])
plt.title("Military Spending Comparison")
plt.ylabel("Billion USD")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
